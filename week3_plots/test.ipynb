# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Distribution plot

# %% [markdown]
# Histogram + KDE:

# %%
sns.histplot(tips['total_bill'], kde=True, bins=25)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# KDE Plot

# %%
sns.kdeplot(tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# Rugplot

# %%
sns.rugplot(tips['tip'],
            height=0.2)
# Out:
# <Axes: xlabel='tip'>

# %%
y = [10,20,30,40]
plt.plot(y)
plt.title('Simple Plot',loc='left', fontsize=16, fontweight='bold', fontstyle='italic')
# Out:
# Text(0.0, 1.0, 'Simple Plot')

# %%
day = ['mon','tue','wed','thur','friday']
tip = [10,22,12,43,56]

plt.figure(figsize=(10,6))

plt.subplot(2,2,1)
plt.plot([1,2,3],[1,2,3])

plt.subplot(2,2,2)
plt.plot([-1,-2,-3],[1,2,3])

plt.subplot(2,2,3)
plt.bar(day, tip)

plt.subplot(2,2,4)
plt.scatter(x=[334,55,231,54], y=[112,334,45,66], alpha=0.3)

# %%
import seaborn as sns

# %%
g = sns.FacetGrid(tips, row='smoker', col='time', hue='sex')
g.map(sns.histplot, 'tip')

# %%
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x,y1,x,y2)
plt.xlabel("X values")
plt.ylabel('Y values')
# Out:
# Text(0, 0.5, 'Y values')

# %%
plt.bar(tips['day'],tips['total_bill'])
# Out:
# <BarContainer object of 244 artists>

# %%
brand = ['amazon', 'apple', 'samsung']
sales = [10000,22999,33888]

plt.pie(sales, labels=brand, autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2731c7438c0>,
# ...
#  [Text(0.9808811980691458, 0.49786752783691096, 'amazon'),
#   Text(-0.47728214345290754, 0.9910609242327126, 'apple'),
#   Text(-0.022963416071855522, -1.099760283662904, 'samsung')],
#  [Text(0.5350261080377158, 0.27156410609286047, '14.95%'),
#   Text(-0.2603357146106768, 0.5405786859451159, '34.38%'),
#   Text(-0.012525499675557555, -0.5998692456343112, '50.66%')])

# %%
plt.scatter(tips['total_bill'], tips['tip'])

# %%
plt.hist(tips['tip'], bins=5, rwidth=0.9)
# Out:
# (array([120.,  93.,  24.,   5.,   2.]),
#  array([ 1. ,  2.8,  4.6,  6.4,  8.2, 10. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.boxplot([tips['total_bill'], tips['tip']], labels=['Total', 'Tip'])
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_16076\1490576050.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([tips['total_bill'], tips['tip']], labels=['Total', 'Tip'])
# {'whiskers': [<matplotlib.lines.Line2D at 0x27328c98b90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27328c98e10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27327fbec10>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x27328c99090>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x27328c991d0>,
# ...
#  'means': []}

# %%
sns.barplot(x='day', y='tip', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.countplot(x='day', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.boxplot(data=[tips['total_bill'], tips['tip']])
plt.xticks([0,1], ['total_bill', 'tip'])
# Out:
# ([<matplotlib.axis.XTick at 0x27328ae74d0>,
# ...
#  [Text(0, 0, 'total_bill'), Text(1, 0, 'tip')])

# %%
sns.violinplot(y=tips['tip'])
# Out:
# <Axes: ylabel='tip'>

# %%
sns.stripplot(x='day', y='total_bill',data=tips, hue='sex', jitter=True, dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='tip', data=tips, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.histplot(tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.kdeplot(tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.rugplot(tips['tip'])
sns.set_style('white')
sns.set_context('paper')

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
sns.set_theme(style='whitegrid')
sns.despine(left=True)

# %%
sns.heatmap(tips.corr(numeric_only=True), annot=True, cmap='Set1')
sns.set_context("paper")

# %%
# %matplotlib inline

# %%
sns.clustermap(tips.corr(numeric_only=True), figsize=(5,5), cmap='Set1')

# %%
sns.pairplot(tips, hue='sex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='scatter', palette='Set1')

# %%
x = [1,2,3.4,5,6,7]
y = [2,3,1,3,4.5,2]

plt.plot(x,y)
plt.style.use('dark_background')

plt.xlim(1,10)
plt.ylim(1,10)
# Out:
# (1.0, 10.0)

# %%
plt.bar(tips['day'], tips['tip'])
# Out:
# <BarContainer object of 244 artists>

# %%
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.subplot(2,2,1)
plt.plot([1,2,3,4],[4,3,2,1])

plt.subplot(2,2,2)
plt.plot([2,3,34,4], [1,2,245,2])

# %%
fig, axes = plt.subplots(1,3, figsize=(10,6))

axes[0].bar(tips['day'], tips['tip'])
sns.stripplot(x='day', y='total_bill', data=tips, hue='smoker', jitter=True, ax=axes[1])
axes[2].plot([1,2,3,4])
