# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Univariate Visualizations

# %% [markdown]
# 1. Histogram + KDE

# %%
sns.histplot(tips['tip'], kde=True, bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# 2. Pure KDE Plot:

# %%
sns.kdeplot(tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# 3. Box Plot:

# %%
sns.boxplot(y=tips['tip'])
# Out:
# <Axes: ylabel='tip'>

# %% [markdown]
# 4. voilin plot:

# %%
sns.violinplot(y=tips['tip'])
# Out:
# <Axes: ylabel='tip'>

# %% [markdown]
# 5. Rug Plot:

# %%
sns.rugplot(tips['tip'])
# Out:
# <Axes: xlabel='tip'>

# %% [markdown]
# 6. Countplot

# %%
sns.countplot(x='day', data=tips, palette='pastel')
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_9956\1315346695.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='day', data=tips, palette='pastel')
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### Bivariate Visualization

# %% [markdown]
# 1. Scatter plot with regression

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Adding linear fit

# %%
sns.regplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# 2. jointplot (combo of scatter, hist, KDE):

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='scatter')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %% [markdown]
# 3. Pairplot

# %%
sns.pairplot(tips, hue='sex', palette='Blues')

# %%
sns.pairplot(tips, hue='sex', palette='Blues', kind='reg')

# %% [markdown]
# 4. Swarmplot

# %%
sns.swarmplot(x='day', y='total_bill',hue='sex', data=tips, color='Blue')
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_9956\3108477959.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:Blue'` for the same effect.
#
#   sns.swarmplot(x='day', y='total_bill',hue='sex', data=tips, color='Blue')
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# 5. Stripplot

# %%
sns.stripplot(x='day', y='total_bill', data=tips, jitter=True,hue='sex', dodge=True)
#jitter=True adds random noise to reduce overlap.
#dodge=True separates hue categories side-by-side.
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Multivariate Visualization

# %% [markdown]
# 1. Heatmap

# %%
corr_matrix = tips.corr(numeric_only=True)
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
corr_matrix = tips.corr(numeric_only=True)
sns.heatmap(corr_matrix,annot=True, cmap='coolwarm')
#cmap='coolwarm' colors positive with warm and negative with cool colors.
#annot=True displays correlation values on the heatmap.
# Out:
# <Axes: >

# %% [markdown]
# 2. cluster map

# %%
sns.clustermap(corr_matrix, cmap='viridis', standard_scale=1)
