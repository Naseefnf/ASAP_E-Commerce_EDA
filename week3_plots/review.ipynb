# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
plt.plot([1,2,3,4],[2,3,4,5])

# %%
sns.lineplot(([1,2,3,4],[1,2,3,4]))
# Out:
# <Axes: >

# %%
tip = sns.load_dataset('tips')

# %%
sns.scatterplot(x='total_bill', y='tip', data=tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(x='total_bill', y='tip', data=tip, kind='reg')

# %%
plt.scatter(tip['total_bill'], tip['tip'])
plt.plot(tip['total_bill'], tip['tip'])

# %% [markdown]
# df cols = name, sales, add extra col bonus, bonus = if sales > 50000, bonus = 10%sales else it is 5 % of sales

# %%
df = { 
    "name": ['ahhaha','bjsjs', 'dhhss'],
    "sales": [60000, 56000,45000]
}

df = pd.DataFrame(df)
df
# Out:
#      name  sales
# 0  ahhaha  60000
# 1   bjsjs  56000
# 2   dhhss  45000

# %%
df['bonus'] = df[df['sales'].lam]

# %%
plt.boxplot(tip['tip'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2112f0c0cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2112f0c0f50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2112f0c0b90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2112f0c11d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2112f0c1310>],
#  'means': []}

# %%
a = ['car', 'bike', 'bus']
sales = [2000,3000,2300]

plt.pie(sales, labels=a)
# Out:
# ([<matplotlib.patches.Wedge at 0x2112f0e06e0>,
# ...
#  [Text(0.717088889790365, 0.8341363942061405, 'car'),
#   Text(-1.090845067924353, 0.1416228716878512, 'bike'),
#   Text(0.6037275967770076, -0.9195178023778872, 'bus')])

# %%
a = np.random.randint(1,101,(10,10))
df = pd.Series(a)
plt.imshow(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 a = np.random.randint(1,101,(10,10))
# ----> 2 df = pd.Series(a)
#       3 plt.imshow(a)
#
# File d:\DataScience\venv\Lib\site-packages\pandas\core\series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File d:\DataScience\venv\Lib\site-packages\pandas\core\construction.py:656, in sanitize_array(data, index, dtype, copy, allow_2d)
#     653             subarr = cast(np.ndarray, subarr)
#     654             subarr = maybe_infer_to_datetimelike(subarr)
# --> 656 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
# ...

# %%
a = np.random.randint(1,101,(10,10))
df = pd.DataFrame(a)

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >
