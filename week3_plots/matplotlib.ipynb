# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
x = [1, 2, 3]
y = [4, 5, 6]
plt.figure(figsize=(10,5))
plt.plot(x, y, marker='*')
plt.title("Simple line plot")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %% [markdown]
# Bar charts

# %%
categories = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']
sales = [30, 25, 35, 20, 40]
bar = plt.bar(categories, sales)
plt.bar_label(bar, labels=sales)
plt.title('Sales Data')
plt.xlabel('day')
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.barh(categories,sales)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Scatter plots

# %%
height = [150, 160, 170, 180, 190]
weight = [50, 60, 70, 80, 90]
plt.scatter(height,weight, marker='*')
plt.xlabel('Height')
plt.ylabel('Weight')
# Out:
# Text(0, 0.5, 'Weight')

# %% [markdown]
#  Pie Charts

# %%
sizes = [40, 35, 25]
labels = ['Python', 'Java', 'C++']
plt.pie(sizes, labels=labels, 
        autopct='%0.2f%%',
        explode=[0,0.1,0],
        startangle=90
        )
# Out:
# ([<matplotlib.patches.Wedge at 0x1557e241a90>,
# ...
#  [Text(-1.0461621541481756, 0.33991873621212615, 'Python'),
#   Text(0.544788817647847, -1.0692077179696473, 'Java'),
#   Text(0.7778174453921319, 0.7778174732182725, 'C++')],
#  [Text(-0.5706339022626412, 0.1854102197520688, '40.00%'),
#   Text(0.3177934769612441, -0.6237045021489609, '35.00%'),
#   Text(0.424264061122981, 0.42426407630087587, '25.00%')])

# %% [markdown]
# Histogram

# %%
np.random.seed(0)
sugar_levels = np.random.randint(60, 150, 100)
plt.hist(sugar_levels,bins=5, rwidth=0.5)
# Out:
# (array([19., 18., 20., 20., 23.]),
#  array([ 60. ,  77.6,  95.2, 112.8, 130.4, 148. ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# Box Plot (Box-and-Whisker)

# %%
data1 = np.random.normal(50, 10, 100)
data2 = np.random.normal(60, 15, 100)
plt.boxplot([data1, data2], labels=['Type A', "Type B"])
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_7404\75243016.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=['Type A', "Type B"])
# {'whiskers': [<matplotlib.lines.Line2D at 0x1557e919810>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1557e919a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1557e883390>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1557e919d10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1557e919e50>,
# ...
#  'means': []}

# %% [markdown]
# Subplots (Multiple Plots Together)

# %%
fig, axes = plt.subplots(1, 4, figsize=(10, 4))
sizes = [40, 35, 25]
labels = ['Python', 'Java', 'C++']
axes[0].hist(data1, bins=10, color='lightgreen')
axes[0].set_title('Type A')
axes[1].pie(sizes, labels=labels)
axes[1].set_title('Type B')
axes[2].hist(data1, bins=10, color='lightgreen')
axes[2].set_title('Type A')
plt.tight_layout(rect=(0.8,0,0,0))
plt.show()
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_7404\1270940.py:10: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(rect=(0.8,0,0,0))

# %% [markdown]
# Heatmaps (Advanced, If Wanted)

# %%
matrix = np.random.rand(5, 5)
plt.imshow(matrix, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.title('Random Matrix Heatmap')
plt.show()

# %% [markdown]
# Plot styling and annotations

# %%
height = [150, 160, 170, 180, 190]
weight = [50, 60, 70, 80, 90]
plt.scatter(height,weight, marker='*')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title("Height vs Weight", fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Height vs Weight')

# %%
plt.xticks([0, 1, 2], ['Zero', 'One', 'Two'], rotation=45)
plt.tick_params(axis='x', direction='inout', length=10, color='red')
