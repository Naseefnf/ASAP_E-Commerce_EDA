# %%
import pandas as pd

# %%
data = {"Name":['naseef','akash', 'naja'],
        "Age":[23,23,22],
        "place":['calicut','calicut','vadakara']}

df = pd.DataFrame(data)
df
# Out:
#      Name  Age     place
# 0  naseef   23   calicut
# 1   akash   23   calicut
# 2    naja   22  vadakara

# %%
df['place']
# Out:
# 0     calicut
# 1     calicut
# 2    vadakara
# Name: place, dtype: object

# %%
df.iloc[:2]
# Out:
#      Name  Age    place
# 0  naseef   23  calicut
# 1   akash   23  calicut

# %%
df['marks'] = [22,33,44]

# %%
df
# Out:
#      Name  Age     place  marks
# 0  naseef   23   calicut     22
# 1   akash   23   calicut     33
# 2    naja   22  vadakara     44

# %%
df.drop('place', axis=1, inplace=True)

# %%
df
# Out:
#      Name  Age  marks
# 0  naseef   23     22
# 1   akash   23     33
# 2    naja   22     44

# %%
data = {"Name":['naseef','naseef', 'naja'],
        "Age":[23,23,22],
        "place":['calicut','calicut','vadakara']}

df = pd.DataFrame(data)
df
# Out:
#      Name  Age     place
# 0  naseef   23   calicut
# 1  naseef   23   calicut
# 2    naja   22  vadakara

# %%
df.drop_duplicates()
# Out:
#      Name  Age     place
# 0  naseef   23   calicut
# 2    naja   22  vadakara
