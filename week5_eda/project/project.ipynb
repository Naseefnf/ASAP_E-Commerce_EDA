# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('UberDataset.csv')
df
# Out:
#          Pickup Location              Drop Location         Booking Status  \
# 0              IIT Delhi                 Sohna Road              Completed
# 1                 Nawada            Noida Extension              Completed
# 2            Uttam Nagar                Mayur Vihar              Completed
# 3               Ghitorni     Satguru Ram Singh Marg              Completed
# 4            Rajiv Chowk  New Delhi Railway Station              Completed
# ...                  ...                        ...                    ...
# 149995       Udyog Vihar                Palam Vihar              Completed
# 149996  Anand Vihar ISBT            Vishwavidyalaya              Completed
# 149997       Mayur Vihar                     Meerut  Cancelled by Customer
# 149998           Azadpur            Noida Sector 62              Completed
# 149999           Azadpur                  Cyber Hub              Completed
#
#        Vehicle Type        Date      Time  Ride Distance  Booking Value  \
# 0           Go Mini  2024-01-24  18:39:14          20.20         272.37
# 1             eBike  2024-03-04  14:38:54           6.21          67.67
# 2           Go Mini  2024-08-09  07:31:02          16.17         186.88
# 3              Bike  2024-08-25  15:05:14          10.49          89.87
# 4           Go Mini  2024-03-28  08:04:50          10.32         159.61
# ...             ...         ...       ...            ...            ...
# 149995      Go Mini  2024-06-26  19:37:52          11.06         153.54
# 149996         Bike  2024-04-05  07:21:39           7.15          68.67
# 149997        eBike  2024-06-04  04:24:33          12.48          99.63
# 149998     Go Sedan  2024-05-04  12:04:49          17.41         204.38
# 149999     Go Sedan  2024-09-19  16:37:15           2.34          50.86
#
#        Payment Method  Avg CTAT  ...  Avg VTAT  Customer Rating  \
# 0          Debit Card      4.32  ...      3.02             3.53
# 1          Debit Card      2.49  ...      1.60             4.44
# 2         Uber Wallet      4.40  ...      2.80             4.01
# 3                Cash      4.41  ...      2.56             3.96
# 4         Uber Wallet      4.62  ...      2.54             3.90
# ...               ...       ...  ...       ...              ...
# 149995    Credit Card      5.90  ...      1.74             4.01
# 149996           Cash      3.56  ...      3.26             3.75
# 149997           Cash      9.63  ...      5.21             1.87
# 149998            UPI      4.86  ...      2.99             4.42
# 149999           Cash      4.43  ...      1.73             4.32
#
#         Cancelled Rides by Customer  Reason for cancelling by Customer  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# ...                             ...                                ...
# 149995                          NaN                                NaN
# 149996                          NaN                                NaN
# 149997                          NaN                                NaN
# 149998                          NaN                                NaN
# 149999                          NaN                                NaN
#
#        Cancelled Rides by Driver  Driver Cancellation Reason Incomplete Rides  \
# 0                            NaN                         NaN              NaN
# 1                            NaN                         NaN              1.0
# 2                            NaN                         NaN              NaN
# 3                            NaN                         NaN              NaN
# 4                            NaN                         NaN              NaN
# ...                          ...                         ...              ...
# 149995                       NaN                         NaN              NaN
# 149996                       NaN                         NaN              NaN
# 149997                       NaN                         NaN              NaN
# 149998                       NaN                         NaN              NaN
# 149999                       NaN                         NaN              NaN
#
#         Incomplete Rides Reason    Booking ID   Customer ID
# 0                           NaN  "CNR5884300"  "CID1982111"
# 1             Vehicle Breakdown  "CNR1326809"  "CID4604802"
# 2                           NaN  "CNR8494506"  "CID9202816"
# 3                           NaN  "CNR8906825"  "CID2610914"
# 4                           NaN  "CNR1950162"  "CID9933542"
# ...                         ...           ...           ...
# 149995                      NaN  "CNR6500631"  "CID4337371"
# 149996                      NaN  "CNR2468611"  "CID2325623"
# 149997                      NaN  "CNR6358306"  "CID9925486"
# 149998                      NaN  "CNR3030099"  "CID9415487"
# 149999                      NaN  "CNR3447390"  "CID4108667"
#
# [150000 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Pickup Location', 'Drop Location', 'Booking Status', 'Vehicle Type',
#        'Date', 'Time', 'Ride Distance', 'Booking Value', 'Payment Method',
#        'Avg CTAT', 'Driver Ratings', 'Avg VTAT', 'Customer Rating'],
#       dtype='object')

# %%
df.shape
# Out:
# (150000, 21)

# %%
df.describe()
# Out:
#        Ride Distance  Booking Value       Avg CTAT  Driver Ratings  \
# count  150000.000000  142564.000000  150000.000000   142575.000000
# mean        8.725433     131.852532       4.746230        3.916989
# std         9.358527     130.939397       2.145921        0.511307
# min         0.200000      22.680000       0.200000        1.000000
# 25%         2.390000      52.887500       3.360000        3.620000
# 50%         5.790000      89.940000       4.100000        4.040000
# 75%        11.750000     159.440000       5.290000        4.280000
# max       105.560000    1651.690000      16.980000        5.000000
#
#             Avg VTAT  Customer Rating  Cancelled Rides by Customer  \
# count  142564.000000    150000.000000                      10500.0
# mean        3.545678         3.784936                          1.0
# std         2.848948         0.854073                          0.0
# min         0.100000         1.000000                          1.0
# 25%         2.040000         3.340000                          1.0
# 50%         2.660000         4.050000                          1.0
# 75%         4.000000         4.390000                          1.0
# max        31.760000         5.000000                          1.0
#
#        Cancelled Rides by Driver  Incomplete Rides
# count                    27000.0            9000.0
# mean                         1.0               1.0
# std                          0.0               0.0
# min                          1.0               1.0
# 25%                          1.0               1.0
# 50%                          1.0               1.0
# 75%                          1.0               1.0
# max                          1.0               1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Pickup Location                    150000 non-null  object
#  1   Drop Location                      150000 non-null  object
#  2   Booking Status                     150000 non-null  object
#  3   Vehicle Type                       150000 non-null  object
#  4   Date                               150000 non-null  object
#  5   Time                               150000 non-null  object
#  6   Ride Distance                      150000 non-null  float64
#  7   Booking Value                      142564 non-null  float64
#  8   Payment Method                     142500 non-null  object
#  9   Avg CTAT                           150000 non-null  float64
#  10  Driver Ratings                     142575 non-null  float64
#  11  Avg VTAT                           142564 non-null  float64
#  12  Customer Rating                    150000 non-null  float64
#  13  Cancelled Rides by Customer        10500 non-null   float64
#  14  Reason for cancelling by Customer  10500 non-null   object
#  15  Cancelled Rides by Driver          27000 non-null   float64
#  16  Driver Cancellation Reason         27000 non-null   object
#  17  Incomplete Rides                   9000 non-null    float64
#  18  Incomplete Rides Reason            9000 non-null    object
#  19  Booking ID                         150000 non-null  object
#  20  Customer ID                        150000 non-null  object
# dtypes: float64(9), object(12)
# memory usage: 24.0+ MB

# %% [markdown]
# ## **Dataset overview**
#
# - **Dataset Name:** Uber Riding Dataset
# - **Rows:** 150,000 ride records
# - **Columns:** 15 features per ride entry
# - **Key Features:**
#   - **Date & Time:** When the ride was booked
#   - **Booking and Customer Info:** IDs and status for each booking/customer
#   - **Locations:** Pickup and Drop locations as text
#   - **Vehicle & Payment:** Vehicle type and payment method
# - **Ride Details:**
#   - **Avg VTAT & CTAT:** Average driver and customer times (numeric)
#   - **Booking Value & Ride Distance:** Amount paid and distance traveled
# - **Ratings:**
#   - **Driver Rating & Customer Rating:** Numeric scores for service (some missing values)
# - **Missing Data:**
#   - **Avg VTAT, CTAT, Booking Value, Ride Distance, Driver and Customer Ratings, Payment Method** have some missing entries
# - **Column Types:**
#   - 9 columns are text/object (e.g., IDs, status, location), 6 are numeric (float)

# %% [markdown]
# #### **Dropping Irrelevant Columns: 'booking id' and 'customer id'**
#
#   In data analysis, it's important to remove columns that are not relevant to your analysis. For this dataset, we'll drop the **'booking id'** and **'customer id'** columns using pandas:

# %%
df.drop(['Customer ID','Booking ID'],axis=1,inplace=True)

# %% [markdown]
# ## **Handling Missing Values**

# %%
df.isnull().sum()
# Out:
# Pickup Location                           0
# Drop Location                             0
# Booking Status                            0
# Vehicle Type                              0
# Date                                      0
# Time                                      0
# Ride Distance                             0
# Booking Value                          7436
# Payment Method                         7500
# Avg CTAT                                  0
# Driver Ratings                         7425
# Avg VTAT                               7436
# Customer Rating                           0
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# dtype: int64

# %% [markdown]
# ###

# %%
# Percentage of missing values

(df.isnull().sum()/len(df))*100
# Out:
# Pickup Location                       0.000000
# Drop Location                         0.000000
# Booking Status                        0.000000
# Vehicle Type                          0.000000
# Date                                  0.000000
# Time                                  0.000000
# Ride Distance                         0.000000
# Booking Value                         4.957333
# Payment Method                        5.000000
# Avg CTAT                              0.000000
# Driver Ratings                        4.950000
# Avg VTAT                              4.957333
# Customer Rating                       0.000000
# Cancelled Rides by Customer          93.000000
# Reason for cancelling by Customer    93.000000
# Cancelled Rides by Driver            82.000000
# Driver Cancellation Reason           82.000000
# Incomplete Rides                     94.000000
# Incomplete Rides Reason              94.000000
# dtype: float64

# %% [markdown]
# ###  Dropping Columns due to High Missing Values (>80%)
#
# The following columns have excessive missing values (82–94%) and were removed from the dataset
# as they provide little usable information and could introduce noise:
#
# - **Cancelled Rides by Customer** – 93% missing
# - **Reason for Cancelling by Customer** – 93% missing
# - **Cancelled Rides by Driver** – 82% missing
# - **Driver Cancellation Reason** – 82% missing
# - **Incomplete Rides** – 94% missing
# - **Incomplete Rides Reason** – 94% missing

# %%
df.drop(['Cancelled Rides by Customer','Reason for cancelling by Customer','Cancelled Rides by Driver','Driver Cancellation Reason','Incomplete Rides','Incomplete Rides Reason'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Pickup Location              Drop Location Booking Status Vehicle Type  \
# 0       IIT Delhi                 Sohna Road      Completed      Go Mini
# 1          Nawada            Noida Extension      Completed        eBike
# 2     Uttam Nagar                Mayur Vihar      Completed      Go Mini
# 3        Ghitorni     Satguru Ram Singh Marg      Completed         Bike
# 4     Rajiv Chowk  New Delhi Railway Station      Completed      Go Mini
#
#          Date      Time  Ride Distance  Booking Value Payment Method  \
# 0  2024-01-24  18:39:14          20.20         272.37     Debit Card
# 1  2024-03-04  14:38:54           6.21          67.67     Debit Card
# 2  2024-08-09  07:31:02          16.17         186.88    Uber Wallet
# 3  2024-08-25  15:05:14          10.49          89.87           Cash
# 4  2024-03-28  08:04:50          10.32         159.61    Uber Wallet
#
#    Avg CTAT  Driver Ratings  Avg VTAT  Customer Rating
# 0      4.32            3.60      3.02             3.53
# 1      2.49            4.24      1.60             4.44
# 2      4.40            4.12      2.80             4.01
# 3      4.41            4.04      2.56             3.96
# 4      4.62             NaN      2.54             3.90

# %% [markdown]
# #### Imputing missing values

# %%
numeric=df.select_dtypes('number')
objects=df.select_dtypes('object')

for col in numeric:
    df[col]=df[col].fillna(df[col].median())

for col in objects:
    df[col]=df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# Pickup Location    0
# Drop Location      0
# Booking Status     0
# Vehicle Type       0
# Date               0
# Time               0
# Ride Distance      0
# Booking Value      0
# Payment Method     0
# Avg CTAT           0
# Driver Ratings     0
# Avg VTAT           0
# Customer Rating    0
# dtype: int64

# %% [markdown]
# ## **Handling Outliers**

# %%
numeric=df.select_dtypes('number')

numeric.boxplot()
plt.xticks(rotation=50)
plt.show()

# %%
def outlier_detection(data):
    q1=np.percentile(data,25,method='midpoint')
    q3=np.percentile(data,75,method='midpoint')
    iqr=q3-q1

    lower=q1-(1.5*iqr)
    upper=q3+(1.5*iqr)

    outlier_condition=(data<lower) | (data>upper)
    outlier=data[outlier_condition]
    outlier_index=data[outlier_condition].index
    percentage=(len(outlier)/len(df))*100

    return outlier,outlier_index,percentage

# %%
outliers,indices,percent=outlier_detection(df['Ride Distance'])

# %%
print(outliers.head())
print(percent)
# Out:
# 34    33.96
# 47    38.53
# 54    38.69
# 83    29.52
# 87    45.41
# Name: Ride Distance, dtype: float64
# 5.592

# %%
lower=np.percentile(df['Ride Distance'],5,method='midpoint')
upper=np.percentile(df['Ride Distance'],95,method='midpoint')

df['Ride Distance']=df['Ride Distance'].clip(lower=lower,upper=upper)

# %%
outliers,indices,percent=outlier_detection(df['Avg VTAT'])
print(outliers.head())
print(percent)
# Out:
# 6     17.95
# 10     7.93
# 14     7.33
# 23     7.63
# 30     7.45
# Name: Avg VTAT, dtype: float64
# 12.931813688105528

# %%
lower=np.percentile(df['Avg VTAT'],5,method='midpoint')
upper=np.percentile(df['Avg VTAT'],95,method='midpoint')

df['Avg VTAT']=df['Avg VTAT'].clip(lower=lower,upper=upper)

# %%
outliers,indices,percent=outlier_detection(df['Avg CTAT'])
print(outliers.head())
print(percent)
# Out:
# 22     8.50
# 95     8.02
# 100    8.04
# 115    9.28
# 148    9.56
# Name: Avg CTAT, dtype: float64
# 9.90275671335534

# %%
df.drop(indices,inplace=True)

# %%
outliers,indices,percent=outlier_detection(df['Driver Ratings'])
print(outliers.head())
print(percent)
# Out:
# 18     3.21
# 93     3.19
# 314    3.08
# 355    3.30
# 394    2.95
# Name: Driver Ratings, dtype: float64
# 3.3279622644906337

# %%
df.drop(indices,inplace=True)

# %%
outliers,indices,percent=outlier_detection(df['Customer Rating'])
print(outliers.head())
print(percent)
# Out:
# 28     2.97
# 45     2.45
# 214    2.68
# 268    2.52
# 286    2.97
# Name: Customer Rating, dtype: float64
# 2.232009833134684

# %%
df.drop(indices,inplace=True)

# %%
outliers,indices,percent=outlier_detection(df['Booking Value'])
print(outliers.head())
print(percent)
# Out:
# 25     433.93
# 85     349.32
# 111    341.74
# 114    275.44
# 182    534.91
# Name: Booking Value, dtype: float64
# 5.854564503071575

# %%
numeric=df.select_dtypes('number')

numeric.boxplot()
plt.xticks(rotation=90)
# Out:
# (array([1, 2, 3, 4, 5, 6]),
#  [Text(1, 0, 'Ride Distance'),
#   Text(2, 0, 'Booking Value'),
#   Text(3, 0, 'Avg CTAT'),
#   Text(4, 0, 'Driver Ratings'),
#   Text(5, 0, 'Avg VTAT'),
#   Text(6, 0, 'Customer Rating')])

# %% [markdown]
# ##

# %%
numeric=df.select_dtypes('number')
numeric
# Out:
#         Ride Distance  Booking Value  Avg CTAT  Driver Ratings  Avg VTAT  \
# 0               20.20         272.37      4.32            3.60      3.02
# 1                6.21          67.67      2.49            4.24      1.60
# 2               16.17         186.88      4.40            4.12      2.80
# 3               10.49          89.87      4.41            4.04      2.56
# 4               10.32         159.61      4.62            4.04      2.54
# ...               ...            ...       ...             ...       ...
# 149994           3.59         109.39      3.36            4.36      1.58
# 149995          11.06         153.54      5.90            3.79      1.74
# 149996           7.15          68.67      3.56            4.01      3.26
# 149998          17.41         204.38      4.86            4.04      2.99
# 149999           2.34          50.86      4.43            4.13      1.73
#
#         Customer Rating
# 0                  3.53
# 1                  4.44
# 2                  4.01
# 3                  3.96
# 4                  3.90
# ...                 ...
# 149994             4.93
# 149995             4.01
# 149996             3.75
# 149998             4.42
# 149999             4.32
#
# [104995 rows x 6 columns]

# %%
for i in numeric:
    outlier=[]
    q1=np.percentile(i,25,method='midpoint')
    q3=np.percentile(i,75,method='midpoint')
    iqr=q3-q1
    lower=q1-(1.5*iqr)
    upper=q3+(1.5*iqr)
    if i<lower or i>upper:
        outlier.append(i)

    print(outlier)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[259], line 3
#       1 for i in numeric:
#       2     outlier=[]
# ----> 3     q1=np.percentile(i,25,method='midpoint')
#       4     q3=np.percentile(i,75,method='midpoint')
#       5     iqr=q3-q1
#
# File d:\py311_env\Lib\site-packages\numpy\lib\_function_base_impl.py:4292, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4289     if np.any(weights < 0):
#    4290         raise ValueError("Weights must be non-negative.")
# -> 4292 return _quantile_unchecked(
#    4293     a, q, axis, out, overwrite_input, method, keepdims, weights)
#
# File d:\py311_env\Lib\site-packages\numpy\lib\_function_base_impl.py:4569, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4560 def _quantile_unchecked(a,
#    4561                         q,
#    4562                         axis=None,
#    (...)   4566                         keepdims=False,
#    4567                         weights=None):
#    4568     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4569     return _ureduce(a,
#    4570                     func=_quantile_ureduce_func,
#    4571                     q=q,
#    4572                     weights=weights,
#    4573                     keepdims=keepdims,
#    4574                     axis=axis,
#    4575                     out=out,
#    4576                     overwrite_input=overwrite_input,
#    4577                     method=method)
#
# File d:\py311_env\Lib\site-packages\numpy\lib\_function_base_impl.py:3914, in _ureduce(a, func, keepdims, **kwargs)
#    3911     index_out = (0, ) * nd
#    3912     kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3914 r = func(a, **kwargs)
#    3916 if out is not None:
#    3917     return out
#
# File d:\py311_env\Lib\site-packages\numpy\lib\_function_base_impl.py:4744, in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method)
#    4742     arr = a.copy()
#    4743     wgt = weights
# -> 4744 result = _quantile(arr,
#    4745                    quantiles=q,
#    4746                    axis=axis,
#    4747                    method=method,
#    4748                    out=out,
#    4749                    weights=wgt)
#    4750 return result
#
# File d:\py311_env\Lib\site-packages\numpy\lib\_function_base_impl.py:4876, in _quantile(arr, quantiles, axis, method, out, weights)
#    4874         result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4875         gamma = gamma.reshape(result_shape)
# -> 4876         result = _lerp(previous,
#    4877                     next,
#    4878                     gamma,
#    4879                     out=out)
#    4880 else:
#    4881     # Weighted case
#    4882     # This implements method="inverted_cdf", the only supported weighted
#    4883     # method, which needs to sort anyway.
#    4884     weights = np.asanyarray(weights)
#
# File d:\py311_env\Lib\site-packages\numpy\lib\_function_base_impl.py:4671, in _lerp(a, b, t, out)
#    4657 def _lerp(a, b, t, out=None):
#    4658     """
#    4659     Compute the linear interpolation weighted by gamma on each point of
#    4660     two same shape array.
#    (...)   4669         Output array.
#    4670     """
# -> 4671     diff_b_a = subtract(b, a)
#    4672     # asanyarray is a stop-gap until gh-13105
#    4673     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('<U13'), dtype('<U13')) -> None
